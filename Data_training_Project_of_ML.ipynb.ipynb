# %%
# Step 1: Load data
from google.colab import files
uploaded = files.upload()

file_name =  list(uploaded.keys())[0]
print(file_name)
# Out:
#      <input type="file" id="files-65a67366-9bd6-44f6-ba72-506bb9b43b5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65a67366-9bd6-44f6-ba72-506bb9b43b5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Step 2: split for training and testing

import pandas as pd

#Load the file into a dataframe
data= pd.read_csv(file_name)

#Display the first few rows of the dataset
print("First few rows of the dataset:")
print(data.head())
# Out:
# First few rows of the dataset:
#    Apartment Size (sq ft)  Number of Rooms  House Rent (Taka)
# 0                    3500                4              55000
# 1                     650                2              15000
# 2                    1550                3              35000
# 3                    2200                3              45500
# 4                    1200                3              27000

# %%
# Step 3: split for training and testin

from sklearn.model_selection import train_test_split

# Assuming your data is in a pandas DataFrame called 'data'
# and you want to split based on a column named 'target'

x = data[['Apartment Size (sq ft)', 'Number of Rooms']]
y = data['House Rent (Taka)']

#X = data.drop('target', axis=1)  # Features
#y = data['target']  # Target variable

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Now you have X_train, X_test, y_train, and y_test for your model
print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
# Out:
# Training data shape: (16, 2)
# Testing data shape: (4, 2)

# %%
# Step 4
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Step 5: Predict on the testing data
y_pred = model.predict(X_test)

# %%
# Step 6: Measure accuracy
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
print(f"Model Accuracy (R² Score): {r2:.2f}")
# Out:
# R-squared: 0.44691963306193916
# Model Accuracy (R² Score): 0.45

# %%
# Step 7: Save the model to a file
import pickle

with open('mainul17@student.sust.edu.pkl', 'wb') as file:
    pickle.dump(model, file)

print("Model saved")
# Out:
# Model saved

# %%
# Step 8: Download the save model
from google.colab import files

files.download('mainul17@student.sust.edu.pkl')
